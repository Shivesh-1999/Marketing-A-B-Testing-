# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivesh-1999/Marketing-A-B-Testing-/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("/content/marketing_AB.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  user id test group  converted  total ads most ads day  \
# 0           0  1069124         ad      False        130       Monday
# 1           1  1119715         ad      False         93      Tuesday
# 2           2  1144181         ad      False         21      Tuesday
# 3           3  1435133         ad      False        355      Tuesday
# 4           4  1015700         ad      False        276       Friday
#
#    most ads hour
# 0             20
# 1             22
# 2             18
# 3             10
# 4             14

# %%
df.duplicated(subset = "user id").sum()
# Out:
# np.int64(0)

# %%
df.drop(['Unnamed: 0','user id'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['test group', 'converted', 'total ads', 'most ads day',
#        'most ads hour'],
#       dtype='object')

# %%
#cheack if the categorical variables have appropriate number of levels
df_cat = df[['test group','converted','most ads day','most ads hour']]
df_cat.nunique()
# Out:
# test group        2
# converted         2
# most ads day      7
# most ads hour    24
# dtype: int64

# %%
#Check if the categorical variables have appropriate number of levels
df_cat = df[['test group','converted','most ads day','most ads hour']]
df_cat.nunique()
# Out:
# test group        2
# converted         2
# most ads day      7
# most ads hour    24
# dtype: int64

# %%
#cheack if the categorical variables have appropriate levels
for i in df_cat.columns:
  print(i.upper(), df_cat[i].unique())
# Out:
# TEST GROUP ['ad' 'psa']
# CONVERTED [False  True]
# MOST ADS DAY ['Monday' 'Tuesday' 'Friday' 'Saturday' 'Wednesday' 'Sunday' 'Thursday']
# MOST ADS HOUR [20 22 18 10 14 13 19 11 12 16 21  3 23  4  8  0  2 15  1  6 17  7  9  5]

# %% [markdown]
# Univariate analysis

# %%
variable = 'test group'

plt.figure(figsize= ( 6,4))
#count plot
plt.subplot(1,2,2)
counts = df_cat[variable].value_counts()
plt.pie(counts, labels=counts.index, autopct='%0.2f%%')
plt.title(f'Pie Chart - {variable}')

#Adjust layout
plt.tight_layout()

# show the plot
plt.show()

# %%
variable = 'converted'

plt.figure(figsize= ( 6,4))
#count plot
plt.subplot(1,2,1)
sns.countplot(x=variable, data=df_cat)
plt.title(f'Count Plot - {variable}')
counts = df_cat[variable].value_counts()

# Pie chart
plt.subplot(1,2,2)
plt.pie(counts, labels=counts.index, autopct='%0.2f%%')
plt.title(f'Pie Chart - {variable}')

# Adjust layout
plt.tight_layout()

# show the plots
plt.show()

# %%
variables = 'most ads day'
plt.figure(figsize= ( 6,4))
#count plot
plt.subplot(1,2,1)
counts = df_cat[variables].value_counts()
plt.pie(counts, labels=counts.index, autopct='%0.2f%%')
plt.title(f'Pie Chart - {variables}')

# Adjust layout
plt.tight_layout()

# show the plot
plt.show()

# %%
variable = 'most ads hour'

plt.figure(figsize= ( 8,4))
#count plot
plt.subplot(1,2,1)
sns.countplot(x=variable, data=df_cat, order = df_cat['most ads hour'].value_counts().index)
plt.title(f'Count Plot - {variable}')
plt.xticks(rotation = 90)

#Pie chart
plt.subplot(1,2,2)
counts = df_cat[variable].value_counts()
plt.pie(counts, labels=counts.index, autopct='%0.2f%%')
plt.title(f'Pie Chart - {variable}')

#Adjust layout
plt.tight_layout()

# show the plots
plt.show()

# %%
variable = 'total ads'

plt.figure(figsize= ( 6,4))
#Histogram
plt.subplot(1,2,1)
sns.histplot(x=variable, data=df)
plt.title(f'Histogram - {variable}')

#Pie chart
plt.subplot(1,2,2)
sns.boxenplot(y = variable, data = df)
plt.title(f'Boxen Plot - {variable}')

#Adjust layout
plt.tight_layout()

# show the plots
plt.show()

# %%
#lets check descriptive stats of this feature
df['total ads'].describe()
# Out:
# count    588101.000000
# mean         24.820876
# std          43.715181
# min           1.000000
# 25%           4.000000
# 50%          13.000000
# 75%          27.000000
# max        2065.000000
# Name: total ads, dtype: float64

# %%
variables = 'total ads'
plt.figure(figsize= ( 6,4))
#Hisogram
plt.subplot(1,2,1)
#Filtering the data for a value close to 75th percentile only for better visulization
sns.histplot(x=variables, data=df[df['total ads']< 50] )
plt.title(f'Histogram - {variables}')

#Pie chart
plt.subplot(1,2,2)
sns.boxenplot(y = variables, data = df[df['total ads']< 50])
plt.title(f'Boxen Plot - {variables}')

#Adjust layout
plt.tight_layout()

# show the plots
plt.show()

# %% [markdown]
# Bivariate analysis

# %%
df.columns
# Out:
# Index(['test group', 'converted', 'total ads', 'most ads day',
#        'most ads hour'],
#       dtype='object')

# %%
ct_conversion_test_group = pd.crosstab(df['test group'], df['converted'], normalize = 'index')
ct_conversion_test_group
# Out:
# converted      False     True
# test group
# ad          0.974453  0.025547
# psa         0.982146  0.017854

# %%
ct_conversion_test_group.plot.bar(  stacked = True);

# %%
ct_conversion_test_group = pd.crosstab(df['most ads day'], df['converted'], normalize = 'index')
print(ct_conversion_test_group.sort_values(by = True, ascending = False))
ct_conversion_test_group.plot.bar(  stacked = True);
# Out:
# converted        False     True
# most ads day
# Monday        0.967188  0.032812
# Tuesday       0.970160  0.029840
# Wednesday     0.975058  0.024942
# Sunday        0.975524  0.024476
# Friday        0.977788  0.022212
# Thursday      0.978429  0.021571
# Saturday      0.978949  0.021051

# %%
ct_conversion_test_group = pd.crosstab(df['most ads hour'], df['converted'], normalize = 'index')
print(ct_conversion_test_group.sort_values(by = True, ascending = False))
ct_conversion_test_group.plot.bar(  stacked = True);
# Out:
# converted         False     True
# most ads hour
# 16             0.969228  0.030772
# 20             0.970197  0.029803
# 15             0.970347  0.029653
# 21             0.971077  0.028923
# 17             0.971790  0.028210
# 14             0.971937  0.028063
# 18             0.972620  0.027380
# 19             0.973280  0.026720
# 22             0.973895  0.026105
# 13             0.975323  0.024677
# 12             0.976172  0.023828
# 23             0.977338  0.022662
# 6              0.977756  0.022244
# 11             0.977884  0.022116
# 10             0.978479  0.021521
# 5              0.979085  0.020915
# 8              0.980484  0.019516
# 9              0.980809  0.019191
# 0              0.981575  0.018425
# 7              0.981889  0.018111
# 4              0.984765  0.015235
# 1              0.987089  0.012911
# 3              0.989548  0.010452
# 2              0.992687  0.007313

# %%
sns.boxenplot(x = 'converted', y = 'total ads', data = df);

# %%
sns.boxenplot(x = 'converted', y = 'total ads', data = df[df['total ads']< 50]);

# %% [markdown]
# Statistical Tests

# %%
from scipy.stats import chi2_contingency
alpha = 0.05
for variable in df_cat.columns:
  if variable != 'converted':
    # create a contigency table(cross-tabulation)
    contingency_table = pd.crosstab(df['converted'], df[variable])
    # perform chi-square test
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    # Display the results
    print(  f"Chi-square test for {variable} vs. converted:")
    print(f"Chi-square value: {chi2:.4f}")
    print(f"P-value: {p}")

# check for significance
if p < alpha:
  print("Reject the null hypothesis. There is a significant association between the variables.")
else:
  print("Fail to reject the null hypothesis. There is no significant association between the variables.")
# Out:
# Chi-square test for test group vs. converted:
# Chi-square value: 54.0058
# P-value: 1.9989623063390075e-13
# Chi-square test for most ads day vs. converted:
# Chi-square value: 410.0479
# P-value: 1.932184379244731e-85
# Chi-square test for most ads hour vs. converted:
# Chi-square value: 430.7687
# P-value: 8.027629823696771e-77
# Reject the null hypothesis. There is a significant association between the variables.

# %%
df_cat.columns
# Out:
# Index(['test group', 'converted', 'most ads day', 'most ads hour'], dtype='object')

# %%
from scipy.stats import shapiro,levene, ttest_ind, mannwhitneyu
# step 1: check assumptions
# Normality assumption
shapiro_stat_true, shapiro_p_value_true = shapiro(df[df['converted'] == True]['total ads'])
shapiro_stat_false, shapiro_p_value_false = shapiro(df[df['converted'] == False]['total ads'])

print(f"Shapiro-Wilk test for normality (True group):p-value={shapiro_p_value_true}")
print(f"Shapiro-Wilk test for normality (False group):p-value={shapiro_p_value_false}")

#Equality of variances assumption
levene_stat, levene_p_value = levene(df[df['converted'] == True]['total ads'], df[df['converted'] == False]['total ads'])
print(f"Levene's test for equality of variances:p-value={levene_p_value}")
# Out:
# Shapiro-Wilk test for normality (True group):p-value=1.638680987007771e-98
# Shapiro-Wilk test for normality (False group):p-value=9.883049430735801e-204
# Levene's test for equality of variances:p-value=0.0

# %%
# step 2 : Perform a Suitable test
alpha = 0.05

if shapiro_p_value_true > alpha and shapiro_p_value_false > alpha and levene_p_value > alpha:
# Assumptions met - use t-test for means
  ttest_stat, ttest_p_value = ttest_ind(df[df['converted'] == True]['total ads'], df[df['converted'] == False]['total ads'])
  print(f"Independent two-sample t-test: p-value={ttest_p_value}")
else:
    # Assumption not met - use Mann-Whitney u-test for medians
    U_stat, U_p_value = mannwhitneyu(df[df['converted'] == True]['total ads'], df[df['converted'] == False]['total ads'])
    print(f"Mann-Whitney U-test: p-value={U_p_value}")
# Out:
# Mann-Whitney U-test: p-value=0.0
